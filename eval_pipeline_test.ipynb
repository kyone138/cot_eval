# %%
pip install wheel deepeval pyarrow pandas fastparquet langchain-text-splitters huggingface_hub ragas==0.0.11 python-dotenv evaluate rouge_score langchain-openai transformers langchain langchainhub langchain-huggingface faiss-cpu langchain-community sentence_transformers

# %%
import pandas as pd
import evaluate
from langchain_openai import ChatOpenAI
from langchain.chains import RetrievalQA
import getpass
import torch

# %%
import os
from dotenv import load_dotenv
load_dotenv()
OPENAI_API_KEY = "api_key"

# %%
from ragas.langchain.evalchain import RagasEvaluatorChain
from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    context_relevancy,
    context_recall
)

# %%
llm = ChatOpenAI(model="gpt-4o-mini", openai_api_key=OPENAI_API_KEY)

# %%
ucsc_qa_df = pd.read_csv("qa.csv", index_col=0)
ucsc_qa_df
# Out:
#                                                questions  \
# index
# 0               Who can be a member of the Boating Club?
# 1      What classes does the boating center offer to ...
# 2                         When is the boating club open?
# 3                   What boats are available to members?
# 4               How much does a boating membership cost?
# ...                                                  ...
# 107    What if I don't fulfill the general education ...
# 108                                      What is UC TAP?
# 109                When are acceptance notices sent out?
# 110    What are the Cross-Campus and Simultaneous Enr...
# 111      Can I talk to an adviser during a campus visit?
#
#                                                  answers  \
# index
# 0      Everyone is welcome to join! If you do not hav...
# 1      We offer all levels of sailing (dinghy and kee...
# 2      The club is open year-round, Saturday and Sund...
# 3      Sailing vessels for weekend use currently incl...
# 4      UCSC Student Membership: $45\nNon-Student Quar...
# ...                                                  ...
# 107    If you don't satisfy general education require...
# 108    UC Transfer Admission Planner (UC TAP) is an o...
# 109    For fall quarter acceptance, notices are sent ...
# 110    Undergraduate students enrolled at UCSC may en...
# 111    Advisers are available to answer your question...
#
#                         source_name  \
# index
# 0      UCSC Boating Recreation FQAs
# 1      UCSC Boating Recreation FQAs
# 2      UCSC Boating Recreation FQAs
# 3      UCSC Boating Recreation FQAs
# 4      UCSC Boating Recreation FQAs
# ...                             ...
# 107    Undergraduate Admissions FAQ
# 108    Undergraduate Admissions FAQ
# 109    Undergraduate Admissions FAQ
# 110    Undergraduate Admissions FAQ
# 111    Undergraduate Admissions FAQ
#
#                                                   source
# index
# 0           https://recreation.ucsc.edu/boating/faq.html
# 1           https://recreation.ucsc.edu/boating/faq.html
# 2           https://recreation.ucsc.edu/boating/faq.html
# 3           https://recreation.ucsc.edu/boating/faq.html
# 4           https://recreation.ucsc.edu/boating/faq.html
# ...                                                  ...
# 107    https://admissions.ucsc.edu/resources-support/...
# 108    https://admissions.ucsc.edu/resources-support/...
# 109    https://admissions.ucsc.edu/resources-support/...
# 110    https://admissions.ucsc.edu/resources-support/...
# 111    https://admissions.ucsc.edu/resources-support/...
#
# [112 rows x 4 columns]

# %%
import pandas as pd
import evaluate
from transformers import pipeline
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_community.document_loaders import DataFrameLoader
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableParallel, RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain import hub
from langchain_openai import ChatOpenAI
import os
import getpass
import torch
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline
from langchain.llms import HuggingFaceHub
from langchain_openai import OpenAIEmbeddings

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

ucsc_passages_df = pd.read_csv("passage.csv", index_col=0)
ucsc_passge_data_loader = DataFrameLoader(ucsc_passages_df, page_content_column="passage")
ucsc_passage_data = ucsc_passge_data_loader.load()
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100,
    length_function=len,
    is_separator_regex=False,
)
docs = text_splitter.split_documents(ucsc_passage_data)
embeddings = OpenAIEmbeddings(openai_api_key=OPENAI_API_KEY)
db = FAISS.from_documents(docs, embeddings)

# %%
# create evaluation chains
faithfulness_chain = RagasEvaluatorChain(metric=faithfulness)
answer_rel_chain = RagasEvaluatorChain(metric=answer_relevancy)
context_rel_chain = RagasEvaluatorChain(metric=context_relevancy)
context_recall_chain = RagasEvaluatorChain(metric=context_recall)
# Out:
# /home/kyone/miniconda3/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %% [markdown]
# # RAGAS

# %%
src_que_list = ucsc_qa_df['questions'].tolist()
src_ans_list = ucsc_qa_df['answers'].tolist()

# %%
examples = [
    {"query": q, "ground_truths": [src_ans_list[i]]}
    for i, q in enumerate(src_que_list)
]

# %%
print(examples[:1])
# Out:
# [{'query': 'Who can be a member of the Boating Club?', 'ground_truths': ["Everyone is welcome to join! If you do not have any previous sailing or rowing experience, you'll want to take a class with us before becoming a club member."]}]

# %%
from langchain.chains import RetrievalQA
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(temperature=0, openai_api_key=OPENAI_API_KEY)


template = """
Given the following context {context}, answer the question like an advisor would to incoming freshman students at the University of California Santa Cruz. 
Try to be concise with the answer and give as much relevant information as possible. 

Question: {question}
"""

prompt = ChatPromptTemplate.from_template(template)
output_parser = StrOutputParser()
retriever = db.as_retriever()

def format_docs(docs):
    x = "\n\n".join(doc.page_content for doc in docs)
    print(x)
    return x

qa_chain = RetrievalQA.from_chain_type(
    llm,
    retriever=db.as_retriever(),  
    return_source_documents=True,
    chain_type_kwargs={"prompt": prompt}
)

# %%
#generated response
result = qa_chain({"query": src_que_list[7]})
result["result"]
# Out:
# 'Yes, there are additional fees associated with taking out boats after joining the boating club. These fees include guest fees for non-members who will be going out on a boat. The guest fee for UCSC students is $5, and for non-students, it is $10. Guests are limited to one visit per month. Additionally, make sure to pay your membership dues and boat fees online ahead of time, as the boating center will no longer be accepting cash payments on-site.'

# %%
import os

from ragas.langchain.evalchain import RagasEvaluatorChain
from ragas.metrics import (
    faithfulness,
    answer_relevancy,
    context_relevancy,
    context_recall
)

# create evaluation chains
faithfulness_chain = RagasEvaluatorChain(metric=faithfulness)
answer_rel_chain = RagasEvaluatorChain(metric=answer_relevancy)
context_rel_chain = RagasEvaluatorChain(metric=context_relevancy)
context_recall_chain = RagasEvaluatorChain(metric=context_recall)
# Out:
# /home/kyone/miniconda3/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
# Recheck the result that we are going to validate.
result.keys()
# Out:
# dict_keys(['query', 'result', 'source_documents'])

# %%
# an example
eval_result = faithfulness_chain(result)
eval_result["faithfulness_score"]
#High faithfulness_score means that there are exact consistency between the source documents and the answer.

# %%
# Assuming we know which question is currently being evaluated (index)
index = 7  
# Extended result dictionary
result_extended = result.copy()
result_extended['ground_truths'] = [src_ans_list[index]]

# %%
result_extended.keys()
# Out:
# dict_keys(['query', 'result', 'source_documents', 'ground_truths'])

# %%
result_extended
# Out:
# {'query': 'Are there additional fees to take out the boats after I join the boating club?',
#  'result': 'Yes, there are additional fees associated with taking out boats after joining the boating club. These fees include guest fees for non-members who will be going out on a boat. The guest fee for UCSC students is $5, and for non-students, it is $10. Guests are limited to one visit per month. Additionally, make sure to pay your membership dues and boat fees online ahead of time, as the boating center will no longer be accepting cash payments on-site.',
#  'source_documents': [Document(metadata={'link': 'https://recreation.ucsc.edu/boating/community-club.html', ' comments': nan}, page_content='Cost\nClub Membership Fees:\n\nUCSC Student Membership: $45\n\nNon-Student Quarterly Membership:  $150\n\nNon-Student Annual Membership:  $500\n\nFamily Discount: First member full price, additional members half price\n\nThere are a few minor fees associated with taking boats out. Guest fees apply to any non-member who will be going out on a boat.\n\nStudent Guest Fee:  $5\n\nNon-Student Guest Fee:  $10\n\n*Guests are limited to one visit per month.'),
#   Document(metadata={'link': 'https://recreation.ucsc.edu/boating/community-club.html', ' comments': nan}, page_content="Our boats:\nSailing vessels for weekend use currently include RS Quests, Lasers, RS Visions, a SC27, a Santana 22, a J 24, an Olson 30, and an O'Day 34.\nThe rowing fleet exists of eight Edon training shells, two MAAS AEROS 20s, two MAAS 24s, Bay 21, Pegasus, WinTech 30' double, and a custom-built wooden double. \nWant to take a boat out? Make sure to pay your membership dues and boat fees online ahead of time. The boating center will no longer be accepting cash payments on-site."),
#   Document(metadata={'link': 'https://recreation.ucsc.edu/boating/community-club.html', ' comments': nan}, page_content='Club Membership Fees:\n\nUCSC Student Membership: $45\n\nNon-Student Quarterly Membership:  $150\n\nNon-Student Annual Membership:  $500\n\nFamily Discount: First member full price, additional members half price\n\nThere are a few minor fees associated with taking boats out. Guest fees apply to any non-member who will be going out on a boat.\n\nStudent Guest Fee:  $5\n\nNon-Student Guest Fee:  $10\n\n*Guests are limited to one visit per month.'),
#   Document(metadata={'link': 'https://recreation.ucsc.edu/boating/community-club.html', ' comments': nan}, page_content="Our boats:\n\nSailing vessels for weekend use currently include RS Quests, Lasers, RS Visions, a SC27, a Santana 22, a J 24, an Olson 30, and an O'Day 34.\nThe rowing fleet exists of eight Edon training shells, two MAAS AEROS 20s, two MAAS 24s, Bay 21, Pegasus, WinTech 30' double, and a custom-built wooden double. \nWant to take a boat out? Make sure to pay your membership dues and boat fees online ahead of time. The boating center will no longer be accepting cash payments on-site.")],
#  'ground_truths': ["There are a few minor fees associated with taking boats out. Guest fees apply to any non-member who will be going out on a boat.\n\nStudent Guest Fee:  $5\nNon-Student Guest Fee:  $10\n*Individuals limited to one guest visit per month.\nOutboard-Use Fees are required when taking out the Santanna 22.\n\nStudent outboard fee: $5\nNon-Student outboard fee: $5\nThe hourly boat rental fee applies only to the use of the O'day 34.\n\nStudent Hourly Boat Rental Fee :  $20\nNon-Student Hourly Boat Rental Fee (O'day only):  $30\nMiscellaneous Fees\nLate Boat-Return Fee:  $20\nDamaged Equipment:  Deductible amount:  1% of insured value, $250 minimum per incident\nLost Equipment:  Depreciated replacement cost "]}

# %%
eval_result1 = context_recall_chain(result_extended)
print(eval_result1["context_recall_score"])

# %%
# run the queries as a batch for efficiency
predictions = qa_chain.batch(examples)

# evaluate
print("evaluating...")
r_faithfulness = faithfulness_chain.evaluate(examples, predictions)
r_faithfulness

# %%
# abstract faithfulness_score value
scores_faithfulness = [item['faithfulness_score'] for item in r_faithfulness]

average_score_faithfulness = sum(scores_faithfulness) / len(scores_faithfulness)

print(f"The average faithfulness score is: {average_score_faithfulness}")
# Out:
# The average faithfulness score is: 0.7609461966604824

# %%
predictions[:1]
# Out:
# [{'query': 'Who can be a member of the Boating Club?',
#   'ground_truth': ["Everyone is welcome to join! If you do not have any previous sailing or rowing experience, you'll want to take a class with us before becoming a club member."],
#   'result': 'Community members, UC Santa Cruz students, faculty, and staff can all be members of the Boating Club.',
#   'source_documents': [Document(page_content='Our club exists to give community members, UC Santa Cruz students, faculty, and staff access to equipment that makes it possible to enjoy our beautiful Monterey Bay. The club provides members a unique opportunity to use any number of sailing and rowing vessels under the weekend supervision of the Boating Center dockmaster.', metadata={'link': 'https://recreation.ucsc.edu/boating/community-club.html', ' comments': nan}),
#    Document(page_content='Our club exists to give community members, UC Santa Cruz students, faculty, and staff access to equipment that makes it possible to enjoy our beautiful Monterey Bay. The club provides members a unique opportunity to use any number of sailing and rowing vessels under the weekend supervision of the Boating Center dockmaster.', metadata={'link': 'https://recreation.ucsc.edu/boating/community-club.html', ' comments': nan}),
#    Document(page_content="Our club exists to give community members, UC Santa Cruz students, faculty, and staff access to equipment that makes it possible to enjoy our beautiful Monterey Bay. The club provides members a unique opportunity to use any number of sailing and rowing vessels under the weekend supervision of the Boating Center dockmaster.\nOur boats:\nSailing vessels for weekend use currently include RS Quests, Lasers, RS Visions, a SC27, a Santana 22, a J 24, an Olson 30, and an O'Day 34.\nThe rowing fleet exists of eight Edon training shells, two MAAS AEROS 20s, two MAAS 24s, Bay 21, Pegasus, WinTech 30' double, and a custom-built wooden double. \nWant to take a boat out? Make sure to pay your membership dues and boat fees online ahead of time. The boating center will no longer be accepting cash payments on-site.\nSailing Hours:\nFriday 4:00-7:00 PM (during daylight savings)\nSaturday 12:00-5:00 PM\nSunday 12:00-5:00 PM\nMembers of the Community Boating Club have access to sailboats and rowing shells during club hours. Members must be approved for boat use by the boating directors before checking out a rowing shall or sailboat. Check our calendar for the next available checkout day. If you do not have prior sailing or rowing experience, we offer classes to build your confidence on the water! For class information, click here.\nSailors and rowers are evaluated based on experience and allowed boat use accordingly.", metadata={'link': 'https://recreation.ucsc.edu/boating/community-club.html', ' comments': nan}),
#    Document(page_content='Boating Club Hours\nThe Community Boating Center is open 2 days a week.\nSaturday: 12:00 PM - 5:00 PM\nSunday: 12:00 PM - 5:00 PM', metadata={'link': 'https://recreation.ucsc.edu/boating/index.html', ' comments': nan})]}]

# %%
# evaluate context recall
print("evaluating...")
r_context_recall = context_recall_chain.evaluate(examples, predictions)
r_context_recall
# Out:
# evaluating...
# 100%|██████████| 8/8 [04:03<00:00, 30.38s/it]
# [{'context_recall_score': 0.5},
#  {'context_recall_score': 0.3333333333333333},
#  {'context_recall_score': 1.0},
#  {'context_recall_score': 1.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 1.0},
#  {'context_recall_score': 1.0},
#  {'context_recall_score': 0.38461538461538464},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.5},
#  {'context_recall_score': 1.0},
#  {'context_recall_score': 1.0},
#  {'context_recall_score': 0.5},
#  {'context_recall_score': 1.0},
#  {'context_recall_score': 0.6666666666666666},
#  {'context_recall_score': 0.5},
#  {'context_recall_score': 1.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 1.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 1.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 1.0},
#  {'context_recall_score': 0.25},
#  {'context_recall_score': 0.3333333333333333},
#  {'context_recall_score': 0.5},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.5},
#  {'context_recall_score': 1.0},
#  {'context_recall_score': 0.5},
#  {'context_recall_score': 0.4},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.5},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.25},
#  {'context_recall_score': 1.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 1.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 1.0},
#  {'context_recall_score': 0.8571428571428571},
#  {'context_recall_score': 1.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 1.0},
#  {'context_recall_score': 0.3333333333333333},
#  {'context_recall_score': 0.9375},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.75},
#  {'context_recall_score': 0.6666666666666666},
#  {'context_recall_score': 1.0},
#  {'context_recall_score': 0.6666666666666666},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 1.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 1.0},
#  {'context_recall_score': 0.5},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.2},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.5},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 1.0},
#  {'context_recall_score': 1.0},
#  {'context_recall_score': 1.0},
#  {'context_recall_score': 0.5},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.3333333333333333},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.6666666666666666},
#  {'context_recall_score': 0.5},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.5},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 1.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.0},
#  {'context_recall_score': 0.5},
#  {'context_recall_score': 0.0}]

# %%
# abstract context_recall_score value
scores_context_recall = [item['context_recall_score'] for item in r_context_recall]

average_score_context_recall = sum(scores_context_recall) / len(scores_context_recall)

print(f"The average context_recall score is: {average_score_context_recall}")
# Out:
# The average context_recall score is: 0.3484755200156986

# %%
print("evaluating...")
r_context_rel = context_rel_chain.evaluate(examples, predictions)
r_context_rel
# Out:
# evaluating...
# 100%|██████████| 8/8 [01:59<00:00, 14.90s/it]
# [{'context_ relevancy_score': 0.21573052141401503},
#  {'context_ relevancy_score': 0.17635535110126843},
#  {'context_ relevancy_score': 0.08829251744530418},
#  {'context_ relevancy_score': 0.0700735178860751},
#  {'context_ relevancy_score': 0.634806474049886},
#  {'context_ relevancy_score': 0.16167906920115152},
#  {'context_ relevancy_score': 0.21573052141401503},
#  {'context_ relevancy_score': 1.111678679784139},
#  {'context_ relevancy_score': 0.08065977195898691},
#  {'context_ relevancy_score': 0.30834452311197913},
#  {'context_ relevancy_score': 0.10743985573450723},
#  {'context_ relevancy_score': 0.20254628111918765},
#  {'context_ relevancy_score': 0.18505053293137322},
#  {'context_ relevancy_score': 0.15312984585762024},
#  {'context_ relevancy_score': 0.011381114522616068},
#  {'context_ relevancy_score': 0.12148579955101013},
#  {'context_ relevancy_score': 0.19428299665451051},
#  {'context_ relevancy_score': 0.3238077561060587},
#  {'context_ relevancy_score': 0.10465717315673828},
#  {'context_ relevancy_score': 0.048594319820404054},
#  {'context_ relevancy_score': 0.138840913772583},
#  {'context_ relevancy_score': 0.060742899775505066},
#  {'context_ relevancy_score': 0.12148579955101013},
#  {'context_ relevancy_score': 0.053993688689337835},
#  {'context_ relevancy_score': 0.10207508739672208},
#  {'context_ relevancy_score': 0.5820629596710205},
#  {'context_ relevancy_score': 0.02977066419341348},
#  {'context_ relevancy_score': 0.0764479072470414},
#  {'context_ relevancy_score': 0.10462858279546101},
#  {'context_ relevancy_score': 0.971886396408081},
#  {'context_ relevancy_score': 0.24297159910202026},
#  {'context_ relevancy_score': 0.043098370234171554},
#  {'context_ relevancy_score': 0.016472650786577645},
#  {'context_ relevancy_score': 0.020678433966129384},
#  {'context_ relevancy_score': 0.01833747917751096},
#  {'context_ relevancy_score': 0.01833747917751096},
#  {'context_ relevancy_score': 0.05716978802400477},
#  {'context_ relevancy_score': 0.021597475475735137},
#  {'context_ relevancy_score': 0.1619810660680135},
#  {'context_ relevancy_score': 0.4859431982040405},
#  {'context_ relevancy_score': 0.9675499200820923},
#  {'context_ relevancy_score': 0.323962132136027},
#  {'context_ relevancy_score': 0.3779258728027344},
#  {'context_ relevancy_score': 0.19394266605377197},
#  {'context_ relevancy_score': 0.9714853763580322},
#  {'context_ relevancy_score': 0.971886396408081},
#  {'context_ relevancy_score': 0.19445545673370362},
#  {'context_ relevancy_score': 1.2143657356500626},
#  {'context_ relevancy_score': 0.2590645790100098},
#  {'context_ relevancy_score': 0.971886396408081},
#  {'context_ relevancy_score': 0.10798737737867567},
#  {'context_ relevancy_score': 0.09718863964080811},
#  {'context_ relevancy_score': 0.19437727928161622},
#  {'context_ relevancy_score': 0.4859431982040405},
#  {'context_ relevancy_score': 0.971886396408081},
#  {'context_ relevancy_score': 0.9726373553276062},
#  {'context_ relevancy_score': 0.24260732531547546},
#  {'context_ relevancy_score': 0.19437727928161622},
#  {'context_ relevancy_score': 1.0684145331382753},
#  {'context_ relevancy_score': 0.3239530523618062},
#  {'context_ relevancy_score': 0.088353308764371},
#  {'context_ relevancy_score': 0.19445545673370362},
#  {'context_ relevancy_score': 0.971886396408081},
#  {'context_ relevancy_score': 0.32382291555404663},
#  {'context_ relevancy_score': 0.24306932091712952},
#  {'context_ relevancy_score': 0.323962132136027},
#  {'context_ relevancy_score': 0.32386620839436847},
#  {'context_ relevancy_score': 0.005367346107959747},
#  {'context_ relevancy_score': 0.12148579955101013},
#  {'context_ relevancy_score': 0.9708346128463745},
#  {'context_ relevancy_score': 0.24316829442977905},
#  {'context_ relevancy_score': 0.162046213944753},
#  {'context_ relevancy_score': 0.9695898294448853},
#  {'context_ relevancy_score': 0.2427913397550583},
#  {'context_ relevancy_score': 0.1619810660680135},
#  {'context_ relevancy_score': 0.7256305813789368},
#  {'context_ relevancy_score': 0.323962132136027},
#  {'context_ relevancy_score': 0.2912057518959046},
#  {'context_ relevancy_score': 0.9707293510437012},
#  {'context_ relevancy_score': 0.323962132136027},
#  {'context_ relevancy_score': 0.138840913772583},
#  {'context_ relevancy_score': 0.24319136142730713},
#  {'context_ relevancy_score': 1.1577678322792053},
#  {'context_ relevancy_score': 0.323962132136027},
#  {'context_ relevancy_score': 0.1619810660680135},
#  {'context_ relevancy_score': 0.19437727928161622},
#  {'context_ relevancy_score': 0.323962132136027},
#  {'context_ relevancy_score': 0.24297159910202026},
#  {'context_ relevancy_score': 0.12963998317718506},
#  {'context_ relevancy_score': 0.1713583504452425},
#  {'context_ relevancy_score': 0.38898205757141113},
#  {'context_ relevancy_score': 0.258880180971963},
#  {'context_ relevancy_score': 0.4861312508583069},
#  {'context_ relevancy_score': 0.9722811579704285},
#  {'context_ relevancy_score': 0.1932161808013916},
#  {'context_ relevancy_score': 0.4854780435562134},
#  {'context_ relevancy_score': 0.6065737456083298},
#  {'context_ relevancy_score': 0.28982355594635006},
#  {'context_ relevancy_score': 0.48464235663414},
#  {'context_ relevancy_score': 0.323962132136027},
#  {'context_ relevancy_score': 0.9680376052856445},
#  {'context_ relevancy_score': 0.10793960756725735},
#  {'context_ relevancy_score': 0.03889279842376709},
#  {'context_ relevancy_score': 0.24221615493297577},
#  {'context_ relevancy_score': 0.215979708565606},
#  {'context_ relevancy_score': 0.10224693699886923},
#  {'context_ relevancy_score': 0.138840913772583},
#  {'context_ relevancy_score': 0.060742899775505066},
#  {'context_ relevancy_score': 0.9687491059303284},
#  {'context_ relevancy_score': 0.24319136142730713},
#  {'context_ relevancy_score': 0.18503325326102119},
#  {'context_ relevancy_score': 0.08099053303400675}]

# %%
# abstract context_relevancy_score value
scores_context_rel = [item['context_ relevancy_score'] for item in r_context_rel]

average_score_context_rel = sum(scores_context_rel) / len(scores_context_rel)

print(f"The average context_rel score is: {average_score_context_rel}")
# Out:
# The average context_rel score is: 0.3380642893840906

# %%
print("evaluating...")
r_answer_rel = answer_rel_chain.evaluate(examples, predictions)
r_answer_rel
# Out:
# evaluating...
# 100%|██████████| 8/8 [01:59<00:00, 14.92s/it]
# [{'answer_relevancy_score': 0.9380761441335238},
#  {'answer_relevancy_score': 0.9486035333993167},
#  {'answer_relevancy_score': 0.9529776687373164},
#  {'answer_relevancy_score': 0.9287508409938264},
#  {'answer_relevancy_score': 0.9905784682991582},
#  {'answer_relevancy_score': 0.9530294501482075},
#  {'answer_relevancy_score': 0.9471055432847485},
#  {'answer_relevancy_score': 0.977602217501384},
#  {'answer_relevancy_score': 0.8887853359066543},
#  {'answer_relevancy_score': 0.9751316730003912},
#  {'answer_relevancy_score': 0.9882392978585598},
#  {'answer_relevancy_score': 0.9011478645742099},
#  {'answer_relevancy_score': 0.8982183938006174},
#  {'answer_relevancy_score': 0.8901509979510568},
#  {'answer_relevancy_score': 0.9170962702097168},
#  {'answer_relevancy_score': 0.8765891958477233},
#  {'answer_relevancy_score': 0.920794570138721},
#  {'answer_relevancy_score': 0.9564428159961366},
#  {'answer_relevancy_score': 0.9399329407191055},
#  {'answer_relevancy_score': 0.8518916320725793},
#  {'answer_relevancy_score': 0.8506294853167217},
#  {'answer_relevancy_score': 0.919766426394716},
#  {'answer_relevancy_score': 0.8995989592915775},
#  {'answer_relevancy_score': 0.8077373499823807},
#  {'answer_relevancy_score': 0.9066613382486266},
#  {'answer_relevancy_score': 0.9228821726630928},
#  {'answer_relevancy_score': 0.9508776917451431},
#  {'answer_relevancy_score': 0.9590837305992941},
#  {'answer_relevancy_score': 0.8988519825584612},
#  {'answer_relevancy_score': 0.8864721208268472},
#  {'answer_relevancy_score': 0.8934161621215244},
#  {'answer_relevancy_score': 0.8833021440636868},
#  {'answer_relevancy_score': 0.914353013401002},
#  {'answer_relevancy_score': 0.9772846452523102},
#  {'answer_relevancy_score': 0.9437309039032122},
#  {'answer_relevancy_score': 0.8741981973542733},
#  {'answer_relevancy_score': 0.8241108453499111},
#  {'answer_relevancy_score': 0.8803357339485395},
#  {'answer_relevancy_score': 0.8761765579128552},
#  {'answer_relevancy_score': 0.9316830128282646},
#  {'answer_relevancy_score': 0.8899432431401909},
#  {'answer_relevancy_score': 0.964006620892191},
#  {'answer_relevancy_score': 0.9290836263854114},
#  {'answer_relevancy_score': 0.7315102169540951},
#  {'answer_relevancy_score': 0.8894500230202707},
#  {'answer_relevancy_score': 0.8669792184794473},
#  {'answer_relevancy_score': 0.9502624026645051},
#  {'answer_relevancy_score': 0.918061405580413},
#  {'answer_relevancy_score': 0.9290111452030895},
#  {'answer_relevancy_score': 0.9311821036398257},
#  {'answer_relevancy_score': 0.8960096869487645},
#  {'answer_relevancy_score': 0.8521459263881681},
#  {'answer_relevancy_score': 0.819512298652101},
#  {'answer_relevancy_score': 0.9286331072291302},
#  {'answer_relevancy_score': 0.7231319357799105},
#  {'answer_relevancy_score': 0.9373763432022404},
#  {'answer_relevancy_score': 0.8639235642927879},
#  {'answer_relevancy_score': 0.8380544350663693},
#  {'answer_relevancy_score': 0.7328425488930246},
#  {'answer_relevancy_score': 0.9214971448402117},
#  {'answer_relevancy_score': 0.9760625799571289},
#  {'answer_relevancy_score': 0.9502466842267424},
#  {'answer_relevancy_score': 0.7318719192870756},
#  {'answer_relevancy_score': 0.8770933443976575},
#  {'answer_relevancy_score': 0.9296001971131735},
#  {'answer_relevancy_score': 0.8116233865426895},
#  {'answer_relevancy_score': 0.8714688336261783},
#  {'answer_relevancy_score': 0.9068745338004094},
#  {'answer_relevancy_score': 0.8162872955315433},
#  {'answer_relevancy_score': 0.8550534248784457},
#  {'answer_relevancy_score': 0.9327170744305073},
#  {'answer_relevancy_score': 0.9759612383111097},
#  {'answer_relevancy_score': 0.9332349675289158},
#  {'answer_relevancy_score': 0.9338443054098208},
#  {'answer_relevancy_score': 0.717662469648937},
#  {'answer_relevancy_score': 0.8591709691468696},
#  {'answer_relevancy_score': 0.8744298398746367},
#  {'answer_relevancy_score': 0.8430707935508108},
#  {'answer_relevancy_score': 0.9175043116847709},
#  {'answer_relevancy_score': 0.9044867202878962},
#  {'answer_relevancy_score': 0.8133920890342594},
#  {'answer_relevancy_score': 0.9079601013578182},
#  {'answer_relevancy_score': 0.9126671525842983},
#  {'answer_relevancy_score': 0.889585476357814},
#  {'answer_relevancy_score': 0.9640071710172439},
#  {'answer_relevancy_score': 0.9319616097564382},
#  {'answer_relevancy_score': 0.9143647137027314},
#  {'answer_relevancy_score': 0.9539746857923199},
#  {'answer_relevancy_score': 0.9322901192662219},
#  {'answer_relevancy_score': 0.8346302510906716},
#  {'answer_relevancy_score': 0.9200052686332253},
#  {'answer_relevancy_score': 0.9408128783980682},
#  {'answer_relevancy_score': 0.7440556147595618},
#  {'answer_relevancy_score': 0.7276310434471789},
#  {'answer_relevancy_score': 0.9766703608863377},
#  {'answer_relevancy_score': 0.9125530848300691},
#  {'answer_relevancy_score': 0.9235353974196087},
#  {'answer_relevancy_score': 0.8912985647566961},
#  {'answer_relevancy_score': 0.942109329851688},
#  {'answer_relevancy_score': 0.9177547467453367},
#  {'answer_relevancy_score': 0.9302836432897532},
#  {'answer_relevancy_score': 0.8840512255258924},
#  {'answer_relevancy_score': 0.9194391104551198},
#  {'answer_relevancy_score': 0.9775297621619142},
#  {'answer_relevancy_score': 0.8712003895524271},
#  {'answer_relevancy_score': 0.8950201511909821},
#  {'answer_relevancy_score': 0.9924822117817519},
#  {'answer_relevancy_score': 0.930701383898557},
#  {'answer_relevancy_score': 0.9533788312219076},
#  {'answer_relevancy_score': 0.9067497826957545},
#  {'answer_relevancy_score': 0.8448529701457522},
#  {'answer_relevancy_score': 0.9210590668373344}]

# %%
# abstract answer_rel_score value
scores_answer_rel = [item['answer_relevancy_score'] for item in r_answer_rel]

average_score_answer_rel = sum(scores_answer_rel) / len(scores_answer_rel)

print(f"The average answer_rel score is: {average_score_answer_rel}")
# Out:
# The average answer_rel score is: 0.8995641732434604

# %% [markdown]
# # G EVAL

# %%
pip install deepeval ipywidgets
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting deepeval
#   Downloading deepeval-1.0.6-py3-none-any.whl.metadata (985 bytes)
# Collecting requests (from deepeval)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tqdm (from deepeval)
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Collecting pytest (from deepeval)
#   Using cached pytest-8.3.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting tabulate (from deepeval)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting typer (from deepeval)
#   Downloading typer-0.12.4-py3-none-any.whl.metadata (15 kB)
# Collecting rich (from deepeval)
#   Using cached rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Collecting protobuf==4.25.1 (from deepeval)
#   Using cached protobuf-4.25.1-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Collecting pydantic (from deepeval)
#   Using cached pydantic-2.8.2-py3-none-any.whl.metadata (125 kB)
# Collecting sentry-sdk (from deepeval)
#   Using cached sentry_sdk-2.13.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting pytest-repeat (from deepeval)
#   Using cached pytest_repeat-0.9.3-py3-none-any.whl.metadata (4.9 kB)
# Collecting pytest-xdist (from deepeval)
#   Using cached pytest_xdist-3.6.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting portalocker (from deepeval)
#   Using cached portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting langchain (from deepeval)
#   Using cached langchain-0.2.14-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain-core (from deepeval)
#   Downloading langchain_core-0.2.33-py3-none-any.whl.metadata (6.2 kB)
# Collecting langchain-openai (from deepeval)
#   Downloading langchain_openai-0.1.22-py3-none-any.whl.metadata (2.6 kB)
# Collecting ragas (from deepeval)
#   Using cached ragas-0.1.14-py3-none-any.whl.metadata (5.3 kB)
# Collecting docx2txt~=0.8 (from deepeval)
#   Using cached docx2txt-0.8-py3-none-any.whl
# Collecting importlib-metadata>=6.0.2 (from deepeval)
#   Downloading importlib_metadata-8.3.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting tenacity~=8.4.1 (from deepeval)
#   Using cached tenacity-8.4.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting opentelemetry-api==1.25.0 (from deepeval)
#   Downloading opentelemetry_api-1.25.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-sdk==1.25.0 (from deepeval)
#   Downloading opentelemetry_sdk-1.25.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc==1.25.0 (from deepeval)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.25.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting grpcio==1.63.0 (from deepeval)
#   Using cached grpcio-1.63.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (3.2 kB)
# Collecting deprecated>=1.2.6 (from opentelemetry-api==1.25.0->deepeval)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting importlib-metadata>=6.0.2 (from deepeval)
#   Using cached importlib_metadata-7.1.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting googleapis-common-protos~=1.52 (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->deepeval)
#   Using cached googleapis_common_protos-1.63.2-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.25.0 (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->deepeval)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.25.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting opentelemetry-proto==1.25.0 (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->deepeval)
#   Downloading opentelemetry_proto-1.25.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-semantic-conventions==0.46b0 (from opentelemetry-sdk==1.25.0->deepeval)
#   Downloading opentelemetry_semantic_conventions-0.46b0-py3-none-any.whl.metadata (2.3 kB)
# Collecting typing-extensions>=3.7.4 (from opentelemetry-sdk==1.25.0->deepeval)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting zipp>=0.5 (from importlib-metadata>=6.0.2->deepeval)
#   Using cached zipp-3.20.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting PyYAML>=5.3 (from langchain->deepeval)
#   Using cached PyYAML-6.0.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (2.1 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain->deepeval)
#   Using cached SQLAlchemy-2.0.32-cp311-cp311-macosx_10_9_x86_64.whl.metadata (9.6 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain->deepeval)
#   Downloading aiohttp-3.10.5-cp311-cp311-macosx_10_9_x86_64.whl.metadata (7.5 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain->deepeval)
#   Using cached langchain_text_splitters-0.2.2-py3-none-any.whl.metadata (2.1 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain->deepeval)
#   Using cached langsmith-0.1.99-py3-none-any.whl.metadata (13 kB)
# Collecting numpy<2,>=1 (from langchain->deepeval)
#   Using cached numpy-1.26.4-cp311-cp311-macosx_10_9_x86_64.whl.metadata (61 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core->deepeval)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting packaging<25,>=23.2 (from langchain-core->deepeval)
#   Using cached packaging-24.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting annotated-types>=0.4.0 (from pydantic->deepeval)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.20.1 (from pydantic->deepeval)
#   Using cached pydantic_core-2.20.1-cp311-cp311-macosx_10_12_x86_64.whl.metadata (6.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests->deepeval)
#   Using cached charset_normalizer-3.3.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests->deepeval)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->deepeval)
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests->deepeval)
#   Using cached certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# Collecting openai<2.0.0,>=1.40.0 (from langchain-openai->deepeval)
#   Downloading openai-1.41.0-py3-none-any.whl.metadata (22 kB)
# Collecting tiktoken<1,>=0.7 (from langchain-openai->deepeval)
#   Using cached tiktoken-0.7.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (6.6 kB)
# Collecting iniconfig (from pytest->deepeval)
#   Using cached iniconfig-2.0.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting pluggy<2,>=1.5 (from pytest->deepeval)
#   Using cached pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting execnet>=2.1 (from pytest-xdist->deepeval)
#   Using cached execnet-2.1.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting datasets (from ragas->deepeval)
#   Using cached datasets-2.21.0-py3-none-any.whl.metadata (21 kB)
# Collecting langchain-community (from ragas->deepeval)
#   Using cached langchain_community-0.2.12-py3-none-any.whl.metadata (2.7 kB)
# Collecting pysbd>=0.3.4 (from ragas->deepeval)
#   Using cached pysbd-0.3.4-py3-none-any.whl.metadata (6.1 kB)
# Collecting nest-asyncio (from ragas->deepeval)
#   Using cached nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting appdirs (from ragas->deepeval)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->deepeval)
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting pygments<3.0.0,>=2.13.0 (from rich->deepeval)
#   Using cached pygments-2.18.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting click>=8.0.0 (from typer->deepeval)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting shellingham>=1.3.0 (from typer->deepeval)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain->deepeval)
#   Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain->deepeval)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain->deepeval)
#   Using cached attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain->deepeval)
#   Using cached frozenlist-1.4.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain->deepeval)
#   Using cached multidict-6.0.5-cp311-cp311-macosx_10_9_x86_64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain->deepeval)
#   Using cached yarl-1.9.4-cp311-cp311-macosx_10_9_x86_64.whl.metadata (31 kB)
# Collecting wrapt<2,>=1.10 (from deprecated>=1.2.6->opentelemetry-api==1.25.0->deepeval)
#   Using cached wrapt-1.16.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (6.6 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core->deepeval)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain->deepeval)
#   Using cached orjson-3.10.7-cp311-cp311-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (50 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->deepeval)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting anyio<5,>=3.5.0 (from openai<2.0.0,>=1.40.0->langchain-openai->deepeval)
#   Using cached anyio-4.4.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting distro<2,>=1.7.0 (from openai<2.0.0,>=1.40.0->langchain-openai->deepeval)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai<2.0.0,>=1.40.0->langchain-openai->deepeval)
#   Using cached httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting jiter<1,>=0.4.0 (from openai<2.0.0,>=1.40.0->langchain-openai->deepeval)
#   Using cached jiter-0.5.0-cp311-cp311-macosx_10_12_x86_64.whl.metadata (3.6 kB)
# Collecting sniffio (from openai<2.0.0,>=1.40.0->langchain-openai->deepeval)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain->deepeval)
#   Using cached greenlet-3.0.3-cp311-cp311-macosx_11_0_universal2.whl.metadata (3.8 kB)
# Collecting regex>=2022.1.18 (from tiktoken<1,>=0.7->langchain-openai->deepeval)
#   Using cached regex-2024.7.24-cp311-cp311-macosx_10_9_x86_64.whl.metadata (40 kB)
# Collecting filelock (from datasets->ragas->deepeval)
#   Using cached filelock-3.15.4-py3-none-any.whl.metadata (2.9 kB)
# Collecting pyarrow>=15.0.0 (from datasets->ragas->deepeval)
#   Using cached pyarrow-17.0.0-cp311-cp311-macosx_10_15_x86_64.whl.metadata (3.3 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets->ragas->deepeval)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting pandas (from datasets->ragas->deepeval)
#   Using cached pandas-2.2.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (19 kB)
# Collecting xxhash (from datasets->ragas->deepeval)
#   Downloading xxhash-3.5.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets->ragas->deepeval)
#   Using cached multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.6.1,>=2023.1.0 (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets->ragas->deepeval)
#   Using cached fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Collecting huggingface-hub>=0.21.2 (from datasets->ragas->deepeval)
#   Downloading huggingface_hub-0.24.6-py3-none-any.whl.metadata (13 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community->ragas->deepeval)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community->ragas->deepeval)
#   Using cached marshmallow-3.21.3-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community->ragas->deepeval)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai->deepeval)
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai->deepeval)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting python-dateutil>=2.8.2 (from pandas->datasets->ragas->deepeval)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas->datasets->ragas->deepeval)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->datasets->ragas->deepeval)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas->datasets->ragas->deepeval)
#   Using cached six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community->ragas->deepeval)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Downloading deepeval-1.0.6-py3-none-any.whl (302 kB)
# Using cached grpcio-1.63.0-cp311-cp311-macosx_10_9_universal2.whl (10.1 MB)
# Downloading opentelemetry_api-1.25.0-py3-none-any.whl (59 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.25.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_sdk-1.25.0-py3-none-any.whl (107 kB)
# Using cached protobuf-4.25.1-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.25.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.25.0-py3-none-any.whl (52 kB)
# Downloading opentelemetry_semantic_conventions-0.46b0-py3-none-any.whl (130 kB)
# Using cached importlib_metadata-7.1.0-py3-none-any.whl (24 kB)
# Using cached tenacity-8.4.2-py3-none-any.whl (28 kB)
# Using cached langchain-0.2.14-py3-none-any.whl (997 kB)
# Downloading langchain_core-0.2.33-py3-none-any.whl (391 kB)
# Using cached pydantic-2.8.2-py3-none-any.whl (423 kB)
# Using cached pydantic_core-2.20.1-cp311-cp311-macosx_10_12_x86_64.whl (1.8 MB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading langchain_openai-0.1.22-py3-none-any.whl (51 kB)
# Using cached portalocker-2.10.1-py3-none-any.whl (18 kB)
# Using cached pytest-8.3.2-py3-none-any.whl (341 kB)
# Using cached pytest_repeat-0.9.3-py3-none-any.whl (4.2 kB)
# Using cached pytest_xdist-3.6.1-py3-none-any.whl (46 kB)
# Using cached ragas-0.1.14-py3-none-any.whl (163 kB)
# Using cached rich-13.7.1-py3-none-any.whl (240 kB)
# Using cached sentry_sdk-2.13.0-py2.py3-none-any.whl (309 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Downloading typer-0.12.4-py3-none-any.whl (47 kB)
# Downloading aiohttp-3.10.5-cp311-cp311-macosx_10_9_x86_64.whl (397 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached certifi-2024.7.4-py3-none-any.whl (162 kB)
# Using cached charset_normalizer-3.3.2-cp311-cp311-macosx_10_9_x86_64.whl (121 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached execnet-2.1.1-py3-none-any.whl (40 kB)
# Using cached googleapis_common_protos-1.63.2-py2.py3-none-any.whl (220 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Using cached langsmith-0.1.99-py3-none-any.whl (140 kB)
# Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Using cached numpy-1.26.4-cp311-cp311-macosx_10_9_x86_64.whl (20.6 MB)
# Downloading openai-1.41.0-py3-none-any.whl (362 kB)
# Using cached packaging-24.1-py3-none-any.whl (53 kB)
# Using cached pluggy-1.5.0-py3-none-any.whl (20 kB)
# Using cached pygments-2.18.0-py3-none-any.whl (1.2 MB)
# Using cached pysbd-0.3.4-py3-none-any.whl (71 kB)
# Using cached PyYAML-6.0.2-cp311-cp311-macosx_10_9_x86_64.whl (184 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached SQLAlchemy-2.0.32-cp311-cp311-macosx_10_9_x86_64.whl (2.1 MB)
# Using cached tiktoken-0.7.0-cp311-cp311-macosx_10_9_x86_64.whl (961 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Using cached zipp-3.20.0-py3-none-any.whl (9.4 kB)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached datasets-2.21.0-py3-none-any.whl (527 kB)
# Using cached iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Using cached langchain_community-0.2.12-py3-none-any.whl (2.3 MB)
# Using cached nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl (12 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached anyio-4.4.0-py3-none-any.whl (86 kB)
# Using cached attrs-24.2.0-py3-none-any.whl (63 kB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached frozenlist-1.4.1-cp311-cp311-macosx_10_9_x86_64.whl (55 kB)
# Using cached fsspec-2024.6.1-py3-none-any.whl (177 kB)
# Using cached greenlet-3.0.3-cp311-cp311-macosx_11_0_universal2.whl (271 kB)
# Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Downloading huggingface_hub-0.24.6-py3-none-any.whl (417 kB)
# Using cached jiter-0.5.0-cp311-cp311-macosx_10_12_x86_64.whl (284 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached multidict-6.0.5-cp311-cp311-macosx_10_9_x86_64.whl (30 kB)
# Using cached orjson-3.10.7-cp311-cp311-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (251 kB)
# Using cached pyarrow-17.0.0-cp311-cp311-macosx_10_15_x86_64.whl (29.0 MB)
# Using cached regex-2024.7.24-cp311-cp311-macosx_10_9_x86_64.whl (282 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached wrapt-1.16.0-cp311-cp311-macosx_10_9_x86_64.whl (37 kB)
# Using cached yarl-1.9.4-cp311-cp311-macosx_10_9_x86_64.whl (83 kB)
# Using cached filelock-3.15.4-py3-none-any.whl (16 kB)
# Using cached multiprocess-0.70.16-py311-none-any.whl (143 kB)
# Using cached pandas-2.2.2-cp311-cp311-macosx_10_9_x86_64.whl (12.6 MB)
# Downloading xxhash-3.5.0-cp311-cp311-macosx_10_9_x86_64.whl (31 kB)
# Using cached marshmallow-3.21.3-py3-none-any.whl (49 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: pytz, docx2txt, appdirs, zipp, xxhash, wrapt, urllib3, tzdata, typing-extensions, tqdm, tenacity, tabulate, sniffio, six, shellingham, regex, PyYAML, pysbd, pygments, protobuf, portalocker, pluggy, packaging, orjson, numpy, nest-asyncio, mypy-extensions, multidict, mdurl, jsonpointer, jiter, iniconfig, idna, h11, grpcio, greenlet, fsspec, frozenlist, filelock, execnet, distro, dill, click, charset-normalizer, certifi, attrs, annotated-types, aiohappyeyeballs, yarl, typing-inspect, SQLAlchemy, sentry-sdk, requests, python-dateutil, pytest, pydantic-core, pyarrow, opentelemetry-proto, multiprocess, marshmallow, markdown-it-py, jsonpatch, importlib-metadata, httpcore, googleapis-common-protos, deprecated, anyio, aiosignal, tiktoken, rich, pytest-xdist, pytest-repeat, pydantic, pandas, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, huggingface-hub, httpx, dataclasses-json, aiohttp, typer, opentelemetry-semantic-conventions, openai, langsmith, opentelemetry-sdk, langchain-core, datasets, opentelemetry-exporter-otlp-proto-grpc, langchain-text-splitters, langchain-openai, langchain, langchain-community, ragas, deepeval
# Successfully installed PyYAML-6.0.2 SQLAlchemy-2.0.32 aiohappyeyeballs-2.4.0 aiohttp-3.10.5 aiosignal-1.3.1 annotated-types-0.7.0 anyio-4.4.0 appdirs-1.4.4 attrs-24.2.0 certifi-2024.7.4 charset-normalizer-3.3.2 click-8.1.7 dataclasses-json-0.6.7 datasets-2.21.0 deepeval-1.0.6 deprecated-1.2.14 dill-0.3.8 distro-1.9.0 docx2txt-0.8 execnet-2.1.1 filelock-3.15.4 frozenlist-1.4.1 fsspec-2024.6.1 googleapis-common-protos-1.63.2 greenlet-3.0.3 grpcio-1.63.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 huggingface-hub-0.24.6 idna-3.7 importlib-metadata-7.1.0 iniconfig-2.0.0 jiter-0.5.0 jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.14 langchain-community-0.2.12 langchain-core-0.2.33 langchain-openai-0.1.22 langchain-text-splitters-0.2.2 langsmith-0.1.99 markdown-it-py-3.0.0 marshmallow-3.21.3 mdurl-0.1.2 multidict-6.0.5 multiprocess-0.70.16 mypy-extensions-1.0.0 nest-asyncio-1.6.0 numpy-1.26.4 openai-1.41.0 opentelemetry-api-1.25.0 opentelemetry-exporter-otlp-proto-common-1.25.0 opentelemetry-exporter-otlp-proto-grpc-1.25.0 opentelemetry-proto-1.25.0 opentelemetry-sdk-1.25.0 opentelemetry-semantic-conventions-0.46b0 orjson-3.10.7 packaging-24.1 pandas-2.2.2 pluggy-1.5.0 portalocker-2.10.1 protobuf-4.25.1 pyarrow-17.0.0 pydantic-2.8.2 pydantic-core-2.20.1 pygments-2.18.0 pysbd-0.3.4 pytest-8.3.2 pytest-repeat-0.9.3 pytest-xdist-3.6.1 python-dateutil-2.9.0.post0 pytz-2024.1 ragas-0.1.14 regex-2024.7.24 requests-2.32.3 rich-13.7.1 sentry-sdk-2.13.0 shellingham-1.5.4 six-1.16.0 sniffio-1.3.1 tabulate-0.9.0 tenacity-8.4.2 tiktoken-0.7.0 tqdm-4.66.5 typer-0.12.4 typing-extensions-4.12.2 typing-inspect-0.9.0 tzdata-2024.1 urllib3-2.2.2 wrapt-1.16.0 xxhash-3.5.0 yarl-1.9.4 zipp-3.20.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from deepeval.metrics import GEval
from deepeval.test_case import LLMTestCaseParams

# %%
correctness_metric = GEval(
    name="Correctness",
    criteria="Determine whether the actual output is factually correct based on the expected output.",
    # NOTE: you can only provide either criteria or evaluation_steps, and not both
    evaluation_steps=[
        "Check whether the facts in 'actual output' contradicts any facts in 'expected output'",
        "You should also heavily penalize omission of detail",
        "Vague language, or contradicting OPINIONS, are OK"
    ],
    evaluation_params=[LLMTestCaseParams.INPUT, LLMTestCaseParams.ACTUAL_OUTPUT],
)

# %%
from deepeval.test_case import LLMTestCase

# %%
import pandas as pd

# %%
ucsc_qa_df = pd.read_csv("/Users/jonathanmorris/Developer/AIEA/LLM-logic/backend/src/model/new_qa.csv", index_col=0)

# %%
src_que_list = ucsc_qa_df['questions'].tolist()
src_ans_list = ucsc_qa_df['answers'].tolist()
gen_ans_list = ucsc_qa_df["generated_response"].tolist()

# %%
test_case = LLMTestCase(
    input=src_que_list[0],
    actual_output=gen_ans_list[0],
    expected_output=src_ans_list[0]
)
test_case
# Out:
# LLMTestCase(input='Who can be a member of the Boating Club?', actual_output='Members of the Boating Club can include community members, UC Santa Cruz students, faculty, and staff.', expected_output="Everyone is welcome to join! If you do not have any previous sailing or rowing experience, you'll want to take a class with us before becoming a club member.", context=None, retrieval_context=None, additional_metadata=None, comments=None, tools_used=None, expected_tools=None, reasoning=None)

# %%
correctness_metric.measure(test_case)
# Out:
# /Users/jonathanmorris/Developer/AIEA/LLM-logic/.conda/lib/python3.11/site-packages/rich/live.py:231: UserWarning:
# install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# Event loop is already running. Applying nest_asyncio patch to allow async execution...
# /Users/jonathanmorris/Developer/AIEA/LLM-logic/.conda/lib/python3.11/site-packages/rich/live.py:231: UserWarning:
# install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# /Users/jonathanmorris/Developer/AIEA/LLM-logic/.conda/lib/python3.11/site-packages/rich/live.py:231: UserWarning:
# install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
print(correctness_metric.score)
print(correctness_metric.reason)
# Out:
# 0.9094460296041593
# The actual output includes community members, UC Santa Cruz students, faculty, and staff, which aligns with the expected details. It is very comprehensive but slightly vague on whether these are the only eligible members.

# %%
reason = []
score = []
for i in range(len(src_que_list)):
    test_case = LLMTestCase(
    input=src_que_list[i],
    actual_output=gen_ans_list[i],
    expected_output=src_ans_list[i]
    )
    
    correctness_metric.measure(test_case)
    reason.append(correctness_metric.reason) 
    score.append(correctness_metric.score)

# %%
pip install numpy

# %%
import numpy as np

np_score = np.array(score)
np_score.mean()
# Out:
# 0.6766009465005097

# %%
ucsc_qa_df['g_eval_score'] = score
ucsc_qa_df['g_eval_reason'] = reason

# %%
ucsc_qa_df
# Out:
#                                                questions  \
# index
# 0               Who can be a member of the Boating Club?
# 1      What classes does the boating center offer to ...
# 2                         When is the boating club open?
# 3                   What boats are available to members?
# 4               How much does a boating membership cost?
# ...                                                  ...
# 107    What if I don't fulfill the general education ...
# 108                                      What is UC TAP?
# 109                When are acceptance notices sent out?
# 110    What are the Cross-Campus and Simultaneous Enr...
# 111      Can I talk to an adviser during a campus visit?
#
#                                                  answers  \
# index
# 0      Everyone is welcome to join! If you do not hav...
# 1      We offer all levels of sailing (dinghy and kee...
# 2      The club is open year-round, Saturday and Sund...
# 3      Sailing vessels for weekend use currently incl...
# 4      UCSC Student Membership: $45\nNon-Student Quar...
# ...                                                  ...
# 107    If you don't satisfy general education require...
# 108    UC Transfer Admission Planner (UC TAP) is an o...
# 109    For fall quarter acceptance, notices are sent ...
# 110    Undergraduate students enrolled at UCSC may en...
# 111    Advisers are available to answer your question...
#
#                         source_name  \
# index
# 0      UCSC Boating Recreation FQAs
# 1      UCSC Boating Recreation FQAs
# 2      UCSC Boating Recreation FQAs
# 3      UCSC Boating Recreation FQAs
# 4      UCSC Boating Recreation FQAs
# ...                             ...
# 107    Undergraduate Admissions FAQ
# 108    Undergraduate Admissions FAQ
# 109    Undergraduate Admissions FAQ
# 110    Undergraduate Admissions FAQ
# 111    Undergraduate Admissions FAQ
#
#                                                   source  \
# index
# 0           https://recreation.ucsc.edu/boating/faq.html
# 1           https://recreation.ucsc.edu/boating/faq.html
# 2           https://recreation.ucsc.edu/boating/faq.html
# 3           https://recreation.ucsc.edu/boating/faq.html
# 4           https://recreation.ucsc.edu/boating/faq.html
# ...                                                  ...
# 107    https://admissions.ucsc.edu/resources-support/...
# 108    https://admissions.ucsc.edu/resources-support/...
# 109    https://admissions.ucsc.edu/resources-support/...
# 110    https://admissions.ucsc.edu/resources-support/...
# 111    https://admissions.ucsc.edu/resources-support/...
#
#                                       generated_response  \
# index
# 0      Members of the Boating Club can include commun...
# 1      The boating center offers classes for beginner...
# 2      The boating club is open on Saturday and Sunda...
# 3      Members have access to the following sailing v...
# 4      The provided context does not include any info...
# ...                                                  ...
# 107    If you do not complete the IGETC or partial IG...
# 108    UC TAP, or the UC Transfer Admission Planner, ...
# 109    The context does not specify when acceptance n...
# 110    The provided context does not include informat...
# 111    Yes, you can talk to an adviser during a campu...
#
#                                              source_docs  g_eval_score  \
# index
# 0      Our club exists to give community members, UC ...      0.909446
# 1      UC Santa Cruz Community Boating Center is a co...      0.815102
# 2      Boating Club Hours\nThe Community Boating Cent...      0.562117
# 3      Our boats:\nSailing vessels for weekend use cu...      0.964788
# 4      There are a few minor fees associated with tak...      0.369330
# ...                                                  ...           ...
# 107    By the end of the fall term prior to transfer,...      0.873402
# 108    UCSC TPP\nUCSC TAG Step-by-Step\nComplete the ...      0.901846
# 109    First Year\t\nApplication Submission\n\nMay 20...      0.478547
# 110    Graduating student\nDual Admission\nDual Admis...      0.207676
# 111    Take a Campus Tour, and/or attend one of our E...      0.897803
#
#                                            g_eval_reason
# index
# 0      The actual output correctly identifies communi...
# 1      The actual output matches the expected output ...
# 2      The actual output provides specific opening ho...
# 3      The actual output provides an extensive list o...
# 4      The actual output correctly states that the pr...
# ...                                                  ...
# 107    The actual output addresses the consequences o...
# 108    The actual output accurately describes UC TAP,...
# 109    The actual output correctly states that the co...
# 110    The actual output does not provide any informa...
# 111    The actual output confirms that you can talk t...
#
# [112 rows x 8 columns]
